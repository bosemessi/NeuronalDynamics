# %%
# %load_ext autoreload
# %autoreload 2

from brian2 import *
import matplotlib.pyplot as plt
import numpy as np
from random import sample
import numpy.random as rnd
from math import floor
import time
from src import learn, make_cloud, plot_oja_trace, run_oja

# %%
cloud = make_cloud(n=200, ratio=.3, angle=60)
wcourse = learn(cloud, initial_angle=-20, eta=0.04)
plt.scatter(cloud[:, 0], cloud[:, 1], marker=".", alpha=.2)
plt.plot(wcourse[-1, 0], wcourse[-1, 1], "or", markersize=10)
plt.plot(wcourse[:, 0], wcourse[:, 1], "or", markersize=2)
plt.axis('equal')
plt.figure()
plt.plot(wcourse[:, 0], "g")
plt.plot(wcourse[:, 1], "b")
print("The final weight vector w is: ({},{})".format(wcourse[-1,0],wcourse[-1,1]))
# Out:
# The final weight vector w is: (0.5522403805973142,0.8345899298828341)

# %% [markdown]
# # 9.1

# %%
cloud = make_cloud(n=200, ratio=.3, angle=60)
wcourse = learn(cloud, initial_angle=-20, eta=0.2)
plt.scatter(cloud[:, 0], cloud[:, 1], marker=".", alpha=.2)
plt.plot(wcourse[-1, 0], wcourse[-1, 1], "or", markersize=10)
plt.plot(wcourse[:, 0], wcourse[:, 1], "or", markersize=2)
plt.axis('equal')
plt.figure()
plt.plot(wcourse[:, 0], "g")
plt.plot(wcourse[:, 1], "b")
plt.plot(np.linalg.norm(wcourse, axis=1), "k")
print("The final weight vector w is: ({},{})".format(wcourse[-1,0],wcourse[-1,1]))
# Out:
# The final weight vector w is: (0.3362941510644771,0.9515455226706231)

# %% [markdown]
# # 9.2

# %%
cloud = make_cloud(n=2000, ratio=1, angle=0)
wcourse = learn(cloud, initial_angle=-20, eta=0.04)
plt.scatter(cloud[:, 0], cloud[:, 1], marker=".", alpha=.2)
plt.plot(wcourse[-1, 0], wcourse[-1, 1], "or", markersize=10)
plt.plot(wcourse[:, 0], wcourse[:, 1], "or", markersize=2)
plt.axis('equal')
plt.figure()
plt.plot(wcourse[:, 0], "g")
plt.plot(wcourse[:, 1], "b")

print("The final weight vector w is: ({},{})".format(wcourse[-1,0],wcourse[-1,1]))
# Out:
# The final weight vector w is: (-1.001673007388636,-0.11121572538449143)

# %%
cloud = make_cloud(n=2000, ratio=1, angle=0)
wcourse = learn(cloud, initial_angle=-20, eta=0.2)
plt.scatter(cloud[:, 0], cloud[:, 1], marker=".", alpha=.2)
plt.plot(wcourse[-1, 0], wcourse[-1, 1], "or", markersize=10)
plt.plot(wcourse[:, 0], wcourse[:, 1], "or", markersize=2)
plt.axis('equal')
plt.figure()
plt.plot(wcourse[:, 0], "g")
plt.plot(wcourse[:, 1], "b")

print("The final weight vector w is: ({},{})".format(wcourse[-1,0],wcourse[-1,1]))
# Out:
# The final weight vector w is: (0.36746088054929565,-0.9554164915316541)

# %% [markdown]
# # 9.4

# %%
cloud = (3,5) + make_cloud(n=2000, ratio=0.4, angle=-45)
wcourse = learn(cloud, initial_angle=-20, eta=0.04)
plt.scatter(cloud[:, 0], cloud[:, 1], marker=".", alpha=.2)
plt.arrow(x=0,y=0, dx=wcourse[-1, 0], dy=wcourse[-1, 1], color="red",width=0.05)
# plt.plot(wcourse[:, 0], wcourse[:, 1], "or", markersize=2)
plt.axis('equal')
plt.figure()
plt.plot(wcourse[:, 0], "g")
plt.plot(wcourse[:, 1], "b")

print("The final weight vector w is: ({},{})".format(wcourse[-1,0],wcourse[-1,1]))
# Out:
# The final weight vector w is: (0.945404860306297,0.8969560414571914)
